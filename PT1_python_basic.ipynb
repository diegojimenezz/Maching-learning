# %% [markdown]
# #descripción:
# ..........
#
#
# *   @author: Diego Andres Jimenez Neva
# *   @date: 2022/02/12
# *   @Description: this notebook python show exercices in python

# %% [markdown]
# #Ejercicios basicos

# %% [markdown]
# ##Ejercicio 1:productos + Iva

# %%
prod1= int(input("input 1° product:"))
prod2= int(input("input 2° product:"))
prod3= int(input("input 3° product:"))
prod4= int(input("input 4° product:"))
prod5= int(input("input 5° product:"))
suma = (prod1+prod2+prod3+prod4+prod5)
iva = suma*0.19
total= suma + iva
print("valor bruto:",suma,"\nIva:",iva,"\nTotal:", total)

# %% [markdown]
# ###Version python

# %%
prod1,prod2,prod3,prod4,prod5 = input("input,1°,2°,3°,4° and 5° product with,separate:").split(",")
suma = (prod1+prod2+prod3+prod4+prod5)
print("valor bruto:",suma,"\nIva:",(suma*0.19),"\nTotal:",(suma+(suma*0.19)))

# %% [markdown]
# ###Ejercicio de promedio

# %%
number1= int(input("Enter the first number"))
number2= int(input("Enter the second number"))
number3= int(input("Enter the third number"))
suma=(number1+number2+number3)
average=suma/3
if(number1>number2 and number1>number3):
  print("the largest number is:", number1)
elif(number2>number3 and number2>number1):
  print("the largest number is:", number2)
else:
  print("the largest number is:", number3)
  print("average",average)

# %% [markdown]
# ###Average version python

# %%
number1,number2,number3= input("enter three numbers",":").split(",")
print("the largest number is:",max(number1,number2,number3),"\nMinium nummber is:", min (number1,number2,number3),"\nAverage",int(int(number1)+int(number2)int(number3))\3)
